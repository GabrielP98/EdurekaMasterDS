# %% [markdown]
# **Objective:**
# * Use k-means clustering for image segmentation and to identify dominant color in the image.
#
# **1. Open and display the image “dog.jpeg”. Convert the image in to numpy array,so that i can be   used in further processing.**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
from math import sqrt

#Visualisation frameworks
import matplotlib.pyplot as plt
# %matplotlib inline  
import seaborn as sns

from skimage.io import imread

# %%
img = imread("C:/Users/gabri/Desktop/Data Science/Python/Python for Data Science - Edureka/Module 10 - Unsupervised Learning/dogs.jpeg") / 255

plt.imshow(img)
plt.title('Original')
plt.show()

# %% [markdown]
# **2. Find out the dimensions of the image and convert it in to a two-dimensional array.**

# %%
image_2D = img.reshape(img.shape[0]*img.shape[1], img.shape[2])
image_2D.shape
# Out:
# (50320, 3)

# %% [markdown]
# **3.Use kmeans clustering with k set to 3 and cluster the image.**

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=0).fit(image_2D)

# %% [markdown]
# **4. Predict the cluster label of every pixel in the image and plot it back as an image.**

# %%
clustered = kmeans.cluster_centers_[kmeans.labels_]

clustered_3D = clustered.reshape(img.shape[0], img.shape[1], img.shape[2])

plt.imshow(clustered_3D)
plt.title('Clustered Image')
plt.show()

# %% [markdown]
# **5. Find out the three dominant color in the image.**

# %%
kmeans.cluster_centers_
# Out:
# array([[0.82592932, 0.68547411, 0.56341102],
#        [0.9861754 , 0.97122865, 0.95345086],
#        [0.11572434, 0.08462564, 0.08028676]])
